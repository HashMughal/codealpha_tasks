# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import KMeans
from pprint import pprint  # Pretty-print for cleaner output

# --- Load & Merge Datasets ---
print("📂 Loading data... Please wait.")
spotify_df = pd.read_csv("spotify_millsongdata.csv")
music_info_df = pd.read_csv("Music Info.csv")

print("🔗 Combining datasets...")
merged_df = pd.merge(
    spotify_df, music_info_df,
    left_on=["artist", "song"],
    right_on=["artist", "name"],
    how="inner"
)

# Drop unnecessary columns
columns_to_remove = ["name", "link", "track_id", "spotify_id", "spotify_preview_url"]
merged_df.drop(columns=columns_to_remove, inplace=True)

# --- Handle Missing Data ---
print("🔄 Cleaning missing values...")
merged_df["genre"] = merged_df["genre"].fillna("Unknown")
merged_df["tags"] = merged_df["tags"].fillna("").apply(lambda x: x.split(", "))

# --- Normalize Numerical Features ---
numerical_cols = [
    "danceability", "energy", "loudness", "speechiness", "acousticness",
    "instrumentalness", "liveness", "valence", "tempo", "duration_ms"
]

print("📊 Scaling numerical features...")
scaler = MinMaxScaler()
merged_df[numerical_cols] = scaler.fit_transform(merged_df[numerical_cols])

# --- Lyrics-Based Recommendation ---
print("🔠 Processing song lyrics for recommendations...")
tfidf = TfidfVectorizer(stop_words="english")
lyrics_matrix = tfidf.fit_transform(merged_df["text"])
lyrics_similarity = cosine_similarity(lyrics_matrix, lyrics_matrix)

def recommend_songs_by_lyrics(song_title, num_recommendations=5):
    """Finds similar songs based on lyrics."""
    if song_title not in merged_df["song"].values:
        return f"⚠️ Sorry, '{song_title}' is not in the database."
    
    idx = merged_df[merged_df["song"] == song_title].index[0]
    similarity_scores = sorted(
        list(enumerate(lyrics_similarity[idx])),
        key=lambda x: x[1],
        reverse=True
    )[1:num_recommendations+1]
    
    return [merged_df.iloc[i[0]][["artist", "song"]].to_dict() for i in similarity_scores]

# --- Feature-Based Recommendation ---
print("🎵 Analyzing song features for recommendations...")
song_features = merged_df[numerical_cols].values
knn = NearestNeighbors(n_neighbors=6, metric="cosine")
knn.fit(song_features)

def recommend_songs_by_features(song_title, num_recommendations=5):
    """Finds similar songs based on musical features."""
    if song_title not in merged_df["song"].values:
        return f"⚠️ '{song_title}' was not found."
    
    idx = merged_df[merged_df["song"] == song_title].index[0]
    _, indices = knn.kneighbors([song_features[idx]])

    return [merged_df.iloc[i][["artist", "song"]].to_dict() for i in indices[0][1:num_recommendations+1]]

# --- Genre-Based Recommendation ---
print("🎼 Grouping songs by genre clusters...")
genre_mapping = {genre: idx for idx, genre in enumerate(merged_df["genre"].unique())}
merged_df["genre_code"] = merged_df["genre"].map(genre_mapping)

kmeans = KMeans(n_clusters=10, random_state=42, n_init=10)
merged_df["cluster"] = kmeans.fit_predict(song_features)

def recommend_songs_by_genre(song_title, num_recommendations=5):
    """Suggests songs from the same genre cluster."""
    if song_title not in merged_df["song"].values:
        return f"⚠️ '{song_title}' is not in the database."
    
    song_cluster = merged_df.loc[merged_df["song"] == song_title, "cluster"].values[0]
    similar_songs = merged_df[merged_df["cluster"] == song_cluster].sample(n=num_recommendations, random_state=42)
    
    return similar_songs[["artist", "song"]].to_dict(orient="records")

# --- Sample Songs to Test ---
sample_songs = [
    "Dancing Queen", "Bohemian Rhapsody", "Hotel California", "Stairway to Heaven",
    "Shake It Off", "Someone Like You", "Blinding Lights", "Shape of You",
    "Lose Yourself", "Sicko Mode", "Stronger", "Titanium", "Animals", "Radioactive"
]

# --- Generate Recommendations for Each Song ---
for song in sample_songs:
    print(f"\n🎶 === Recommendations for: {song} ===\n")
    
    # Lyrics-Based Recommendations
    lyrics_recs = recommend_songs_by_lyrics(song, 5)
    print("📖 Based on Lyrics:")
    pprint(lyrics_recs)
    
    # Feature-Based Recommendations
    feature_recs = recommend_songs_by_features(song, 5)
    print("\n🎧 Based on Musical Features:")
    pprint(feature_recs)
    
    # Genre-Based Recommendations
    genre_recs = recommend_songs_by_genre(song, 5)
    print("\n🎼 Based on Genre Similarity:")
    pprint(genre_recs)
    
    print("=" * 60)
# Out:
# 📂 Loading data... Please wait.
# 🔗 Combining datasets...
# 🔄 Cleaning missing values...
# 📊 Scaling numerical features...
# 🔠 Processing song lyrics for recommendations...
# 🎵 Analyzing song features for recommendations...
# 🎼 Grouping songs by genre clusters...
#
# 🎶 === Recommendations for: Dancing Queen ===
#
# 📖 Based on Lyrics:
# [{'artist': 'Leo Sayer', 'song': 'You Make Me Feel Like Dancing'},
#  {'artist': 'Black Sabbath', 'song': 'Air Dance'},
#  {'artist': 'Xandria', 'song': 'Dancer'},
#  {'artist': 'High School Musical', 'song': 'Can I Have This Dance'},
#  {'artist': 'Justin Bieber', 'song': 'First Dance'}]
#
# 🎧 Based on Musical Features:
# [{'artist': 'Jimi Hendrix', 'song': 'Long Hot Summer Night'},
#  {'artist': 'Dave Matthews Band', 'song': 'Rapunzel'},
#  {'artist': 'Steely Dan', 'song': 'Kid Charlemagne'},
#  {'artist': 'Supertramp', 'song': 'The Logical Song'},
#  {'artist': 'Violent Femmes', 'song': 'Country Death Song'}]
#
# 🎼 Based on Genre Similarity:
# [{'artist': 'Dave Matthews Band', 'song': 'Lover Lay Down'},
#  {'artist': 'Deep Purple', 'song': 'Highway Star'},
#  {'artist': 'Within Temptation', 'song': 'The Cross'},
#  {'artist': 'Ramones', 'song': 'Here Today, Gone Tomorrow'},
#  {'artist': 'Queen', 'song': 'Sheer Heart Attack'}]
# ============================================================
#
# 🎶 === Recommendations for: Bohemian Rhapsody ===
#
# 📖 Based on Lyrics:
# [{'artist': 'Green Day', 'song': 'Let Yourself Go'},
#  {'artist': 'Etta James', 'song': 'Tell Mama'},
#  {'artist': 'The Beatles', 'song': 'Let It Be'},
#  {'artist': 'Metallica', 'song': 'Mama Said'},
#  {'artist': 'Wet Wet Wet', 'song': 'Love Is All Around'}]
#
# 🎧 Based on Musical Features:
# [{'artist': 'Black Sabbath', 'song': 'Who Are You?'},
#  {'artist': 'Christina Perri', 'song': 'A Thousand Years'},
#  {'artist': 'Xavier Rudd', 'song': 'Come Let Go'},
#  {'artist': 'Europe', 'song': 'Carrie'},
#  {'artist': 'Sia', 'song': 'Blow It All Away'}]
#
# 🎼 Based on Genre Similarity:
# [{'artist': 'Sia', 'song': 'Electric Bird'},
#  {'artist': 'Whiskeytown', 'song': 'Houses On The Hill'},
#  {'artist': 'Xavier Rudd', 'song': 'Set It Up'},
#  {'artist': 'Tom Waits', 'song': 'Jersey Girl'},
#  {'artist': 'Judas Priest', 'song': 'Fire Burns Below'}]
# ============================================================
#
# 🎶 === Recommendations for: Hotel California ===
#
# 📖 Based on Lyrics:
# "⚠️ Sorry, 'Hotel California' is not in the database."
#
# 🎧 Based on Musical Features:
# "⚠️ 'Hotel California' was not found."
#
# 🎼 Based on Genre Similarity:
# "⚠️ 'Hotel California' is not in the database."
# ============================================================
#
# 🎶 === Recommendations for: Stairway to Heaven ===
#
# 📖 Based on Lyrics:
# "⚠️ Sorry, 'Stairway to Heaven' is not in the database."
#
# 🎧 Based on Musical Features:
# "⚠️ 'Stairway to Heaven' was not found."
#
# 🎼 Based on Genre Similarity:
# "⚠️ 'Stairway to Heaven' is not in the database."
# ============================================================
#
# 🎶 === Recommendations for: Shake It Off ===
#
# 📖 Based on Lyrics:
# "⚠️ Sorry, 'Shake It Off' is not in the database."
#
# 🎧 Based on Musical Features:
# "⚠️ 'Shake It Off' was not found."
#
# 🎼 Based on Genre Similarity:
# "⚠️ 'Shake It Off' is not in the database."
# ============================================================
#
# 🎶 === Recommendations for: Someone Like You ===
#
# 📖 Based on Lyrics:
# [{'artist': 'Incubus', 'song': 'Love Hurts'},
#  {'artist': 'Bee Gees', 'song': "Don't Forget To Remember"},
#  {'artist': 'Michael Jackson', 'song': 'One Day In Your Life'},
#  {'artist': 'Whitney Houston', 'song': 'I Will Always Love You'},
#  {'artist': 'Fiona Apple', 'song': 'Paper Bag'}]
#
# 🎧 Based on Musical Features:
# [{'artist': 'Elton John', 'song': 'Border Song'},
#  {'artist': 'ABBA', 'song': 'Happy New Year'},
#  {'artist': 'Pearl Jam', 'song': 'Just Breathe'},
#  {'artist': 'Josh Groban', 'song': 'It Came Upon A Midnight Clear'},
#  {'artist': 'Ingrid Michaelson', 'song': 'Keep Breathing'}]
#
# 🎼 Based on Genre Similarity:
# [{'artist': 'Grateful Dead', 'song': 'Brokedown Palace'},
#  {'artist': 'James Taylor', 'song': 'Enough To Be On Your Way'},
#  {'artist': 'Nat King Cole', 'song': 'Stardust'},
#  {'artist': 'Frank Sinatra', 'song': "Can't We Be Friends?"},
#  {'artist': 'Leonard Cohen', 'song': 'Suzanne'}]
# ============================================================
#
# 🎶 === Recommendations for: Blinding Lights ===
#
# 📖 Based on Lyrics:
# "⚠️ Sorry, 'Blinding Lights' is not in the database."
#
# 🎧 Based on Musical Features:
# "⚠️ 'Blinding Lights' was not found."
#
# 🎼 Based on Genre Similarity:
# "⚠️ 'Blinding Lights' is not in the database."
# ============================================================
#
# 🎶 === Recommendations for: Shape of You ===
#
# 📖 Based on Lyrics:
# "⚠️ Sorry, 'Shape of You' is not in the database."
#
# 🎧 Based on Musical Features:
# "⚠️ 'Shape of You' was not found."
#
# 🎼 Based on Genre Similarity:
# "⚠️ 'Shape of You' is not in the database."
# ============================================================
#
# 🎶 === Recommendations for: Lose Yourself ===
#
# 📖 Based on Lyrics:
# [{'artist': 'Iggy Pop', 'song': 'Dum Dum Boys'},
#  {'artist': 'Mariah Carey', 'song': "It's Like That"},
#  {'artist': 'Glen Campbell', 'song': 'Southern Nights'},
#  {'artist': 'Avril Lavigne', 'song': 'Keep Holding On'},
#  {'artist': 'Yeah Yeah Yeahs', 'song': 'Rockers To Swallow'}]
#
# 🎧 Based on Musical Features:
# [{'artist': 'Young Jeezy', 'song': 'Crazy World'},
#  {'artist': 'Fatboy Slim', 'song': 'The Rockafeller Skank'},
#  {'artist': 'Young Jeezy', 'song': 'What They Want'},
#  {'artist': 'Wishbone Ash', 'song': "Blowin' Free"},
#  {'artist': 'Eminem', 'song': 'Kim'}]
#
# 🎼 Based on Genre Similarity:
# [{'artist': 'Yeah Yeah Yeahs', 'song': 'Turn Into'},
#  {'artist': 'Unearth', 'song': 'The Great Dividers'},
#  {'artist': 'Marilyn Manson', 'song': 'Just A Car Crash Away'},
#  {'artist': 'Marilyn Manson', 'song': 'Spade'},
#  {'artist': 'Iron Maiden', 'song': 'Face In The Sand'}]
# ============================================================
#
# 🎶 === Recommendations for: Sicko Mode ===
#
# 📖 Based on Lyrics:
# "⚠️ Sorry, 'Sicko Mode' is not in the database."
#
# 🎧 Based on Musical Features:
# "⚠️ 'Sicko Mode' was not found."
#
# 🎼 Based on Genre Similarity:
# "⚠️ 'Sicko Mode' is not in the database."
# ============================================================
#
# 🎶 === Recommendations for: Stronger ===
#
# 📖 Based on Lyrics:
# [{'artist': 'Jennifer Lopez', 'song': 'Get Right'},
#  {'artist': "Guns N' Roses", 'song': 'November Rain'},
#  {'artist': 'Joy Division', 'song': 'Novelty'},
#  {'artist': 'Lynyrd Skynyrd', 'song': 'You Got That Right'},
#  {'artist': 'Scorpions', 'song': 'Animal Magnetism'}]
#
# 🎧 Based on Musical Features:
# [{'artist': 'Insane Clown Posse', 'song': 'Play With Me'},
#  {'artist': 'Red Hot Chili Peppers', 'song': 'Aeroplane'},
#  {'artist': 'Nicki Minaj', 'song': 'Super Bass'},
#  {'artist': 'Michael Jackson', 'song': 'She Drives Me Wild'},
#  {'artist': 'Megadeth', 'song': "Crush 'em"}]
#
# 🎼 Based on Genre Similarity:
# [{'artist': 'Manowar', 'song': 'Metal Daze'},
#  {'artist': 'Marilyn Manson', 'song': 'Coma Black'},
#  {'artist': 'Travis', 'song': 'Pipe Dreams'},
#  {'artist': 'Judas Priest', 'song': 'Worth Fighting For'},
#  {'artist': 'Roxette', 'song': 'The Look'}]
# ============================================================
#
# 🎶 === Recommendations for: Titanium ===
#
# 📖 Based on Lyrics:
# [{'artist': 'Violent Femmes', 'song': 'Add It Up'},
#  {'artist': 'Metallica', 'song': 'Shoot Me Again'},
#  {'artist': 'Radiohead', 'song': 'Feral'},
#  {'artist': 'U2', 'song': 'I Fall Down'},
#  {'artist': 'Ed Sheeran', 'song': 'This'}]
#
# 🎧 Based on Musical Features:
# [{'artist': 'Chris Brown', 'song': "Don't Wake Me Up"},
#  {'artist': 'OneRepublic', 'song': 'Say (All I Need)'},
#  {'artist': 'Travis', 'song': 'Mid-Life Krysis'},
#  {'artist': 'Incubus', 'song': 'Oil And Water'},
#  {'artist': 'Nickelback', 'song': 'Too Bad'}]
#
# 🎼 Based on Genre Similarity:
# [{'artist': 'Manowar', 'song': 'Metal Daze'},
#  {'artist': 'Marilyn Manson', 'song': 'Coma Black'},
#  {'artist': 'Travis', 'song': 'Pipe Dreams'},
#  {'artist': 'Judas Priest', 'song': 'Worth Fighting For'},
#  {'artist': 'Roxette', 'song': 'The Look'}]
# ============================================================
#
# 🎶 === Recommendations for: Animals ===
#
# 📖 Based on Lyrics:
# [{'artist': 'Christina Aguilera', 'song': 'I Got Trouble'},
#  {'artist': 'Depeche Mode', 'song': "Just Can't Get Enough"},
#  {'artist': 'Bruce Springsteen', 'song': "Ain't Got You"},
#  {'artist': 'Tracy Chapman', 'song': 'Fast Car'},
#  {'artist': 'Michael Jackson', 'song': 'She Drives Me Wild'}]
#
# 🎧 Based on Musical Features:
# [{'artist': 'Ozzy Osbourne', 'song': "I Don't Wanna Stop"},
#  {'artist': 'Miley Cyrus', 'song': 'Wake Up America'},
#  {'artist': 'Green Day', 'song': 'Sweet 16'},
#  {'artist': 'Nightwish', 'song': 'Where Were You Last Night'},
#  {'artist': 'Morrissey', 'song': 'All You Need Is Me'}]
#
# 🎼 Based on Genre Similarity:
# [{'artist': 'Scorpions', 'song': "You're Lovin' Me To Death"},
#  {'artist': 'Helloween', 'song': 'Savage'},
#  {'artist': 'Rihanna', 'song': 'We Ride'},
#  {'artist': 'The Jam', 'song': 'Town Called Malice'},
#  {'artist': 'Green Day', 'song': 'Oh Love'}]
# ============================================================
#
# 🎶 === Recommendations for: Radioactive ===
#
# 📖 Based on Lyrics:
# [{'artist': 'Justin Bieber', 'song': 'Up'},
#  {'artist': 'Janis Joplin', 'song': 'Kozmic Blues'},
#  {'artist': 'Misfits', 'song': 'American Psycho'},
#  {'artist': 'Misfits', 'song': 'I Turned Into A Martian'},
#  {'artist': 'Weezer', 'song': 'Hash Pipe'}]
#
# 🎧 Based on Musical Features:
# [{'artist': 'Rihanna', 'song': 'Red Lipstick'},
#  {'artist': 'Christina Aguilera', 'song': 'Nasty Naughty Boy'},
#  {'artist': 'Dave Matthews Band', 'song': 'Hunger For The Great Light'},
#  {'artist': 'Marilyn Manson', 'song': 'The Love Song'},
#  {'artist': 'Tracy Chapman', 'song': 'Telling Stories'}]
#
# 🎼 Based on Genre Similarity:
# [{'artist': 'Dave Matthews Band', 'song': 'Lover Lay Down'},
#  {'artist': 'Deep Purple', 'song': 'Highway Star'},
#  {'artist': 'Within Temptation', 'song': 'The Cross'},
#  {'artist': 'Ramones', 'song': 'Here Today, Gone Tomorrow'},
#  {'artist': 'Queen', 'song': 'Sheer Heart Attack'}]
# ============================================================
